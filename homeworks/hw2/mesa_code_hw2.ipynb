# %%
from hw2_utils import *
from importlib import reload

# %% [markdown]
# ##### QN 2 a) Pressure vs Radius

# %%
#Load the data
model_6_msun = read_data('mid_ms_6_model.data')
model_0_8_msun = read_data('mid_ms_0.8_model.data')

# Some colors
colors = ['magenta','lime']

# %%
params = {
    'df':model_0_8_msun,
    'outfile':'P_vs_R_0.8_model.png',
    'polytropes':[1.5,3],
    'model_name':6.,
    'fac_vals':[0.8e14,3e14],
    'colors':colors,
    'model_fit_params':[[0,0.65,0.5,colors[1],'Region of best fit n=3'],
                        [0,0.15,0.5,colors[0],'Region of Best fit n=1.5']],
    'ssize': 5,
    'x_lims': None,
    'y_lims': None,
    'xlbl': r'Radius $R/R_{\odot}$',
    'plot_linear_R': True,
}

plot_logP_vs_logR(**params)

# %%
params = {
    'df':model_6_msun,
    'outfile':'P_vs_R_6_model.png',
    'polytropes':[1.5,3],
    'model_name':6.,
    'fac_vals':[0.8e15,1.2e15],
    'colors':colors,
    'model_fit_params':[[0,4.2,1,colors[1],'Region of best fit n=3'],
                        [0,1.2,1,colors[0],'Region of best n=1.5']],
    'ssize': 10,
    'x_lims': None,
    'y_lims': None,
    'xlbl': r'Radius ($R/R_{\odot}$)',
    'plot_linear_R': True,
}

plot_logP_vs_logR(**params)

# %%
params = {
    'df': model_6_msun,
    'xlabel': r'Radius ($R/R_{\odot}$)',
    'ylabel': r'$\frac{d\log T}{d\log P}$',
    'title': r'$\frac{d\log T}{d\log P}$ vs. R for a 6 $M_{\odot}$ star',
    'color': 'k',
    'ssize': 10,
    'convection_limit': [0.36,0.4],
    'outfile': 'dlogT_dlogP_vs_R_6_model.png',

}

plotting_dlogT_dlogP_vs_R(**params)

# %%
params = {
    'df': model_0_8_msun,
    'xlabel': r'Radius ($R/R_{\odot}$)',
    'ylabel': r'$\frac{d\log T}{d\log P}$',
    'title': r'$\frac{d\log T}{d\log P}$ vs. R for a 0.8 $M_{\odot}$ star',
    'color': 'k',
    'ssize': 10,
    'convection_limit': [0.36,0.4],
    'outfile': 'dlogT_dlogP_vs_R_0.8_model.png',

}

plotting_dlogT_dlogP_vs_R(**params)

# %%
plot_abundances(model_6_msun,
                model_0_8_msun,
                label1=r'6 $M_{\odot}$',
                label2=r'0.8 $M_{\odot}$',)
