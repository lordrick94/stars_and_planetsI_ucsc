# %% [markdown]
# #### Importing Libraries and Loading the table

# %%
# Import utilities
from hw3_utils import *
import pandas as pd

# %% [markdown]
# ##### Qn 2 a) Cluster selection was done in run_cluster_iterations.py

# %% [markdown]
# #### Qn 2 b)

# %%
# Load the data
data = pd.read_csv('cluster_data_final.csv')

# %%
plot_color_magnitude_diagram(data,boring_plot=True)

# %%
# Plot color-magnitude diagram
points = {
    'p0': (0.35,8),
    'p1': (0.5,9),
    'p2': (1,11.5),
    'p3': (1.5,13),
    'p4': (2,14.3),
    'p5': (2.5,15.5),
    'p6': (3,17),
}
linr_seg = []

for i in range(len(points) - 1):
    x_i = ((points[f'p{i}'], points[f'p{i+1}']))
    linr_seg.append(x_i)

ms_offset = 0.8

plot_ms_fit_params = {
    'xmin': points['p0'][0],
    'xmax': points['p6'][0],
    'max_mag': 16,
    'min_mag': 9,
}

# %%
result_dict = count_stars_above_line(data,linr_seg,ms_offset=ms_offset)

# %%
plot_color_magnitude_diagram(data,line_segments=linr_seg,
                                    ms_offset=ms_offset,
                                    ms_line_color='crimson',
                                    ot_line_color='fuchsia',
                                    plot_ms_curve_fit=None,)

# %%
plot_color_magnitude_diagram(data,line_segments=linr_seg,
                                    ms_offset=ms_offset,
                                    ms_line_color='crimson',
                                    ot_line_color='fuchsia',
                                    plot_ms_curve_fit=plot_ms_fit_params,)

# %%
f_binary = result_dict['num_outliers']/result_dict['num_ms_stars']

print(f'The total number of stars is {len(data)}')
print(f'The fraction of binaries is {f_binary:.3f}')
# Out:
# The total number of stars is 1039
# The fraction of binaries is 0.154

# %%
# Plot a histogram of the number of the mag differences
new_df = mag_differences_and_flux_ratios(data=data,
                                         ms_indices=result_dict['ms_indices'],
                                         ot_indices=result_dict['outlier_indices'],
                                      )

# %%
ot_indices = result_dict['outlier_indices']

# %%
len(data)
# Out:
# 1039

# %%
list_data_columns(new_df)
# Out:
# solution_id
# designation
# source_id
# random_index
# ref_epoch
# ra
# ra_error
# dec
# dec_error
# parallax
# parallax_error
# parallax_over_error
# pm
# pmra
# pmra_error
# pmdec
# pmdec_error
# ra_dec_corr
# ra_parallax_corr
# ra_pmra_corr
# ra_pmdec_corr
# dec_parallax_corr
# dec_pmra_corr
# dec_pmdec_corr
# parallax_pmra_corr
# parallax_pmdec_corr
# pmra_pmdec_corr
# astrometric_n_obs_al
# astrometric_n_obs_ac
# astrometric_n_good_obs_al
# astrometric_n_bad_obs_al
# astrometric_gof_al
# astrometric_chi2_al
# astrometric_excess_noise
# astrometric_excess_noise_sig
# astrometric_params_solved
# astrometric_primary_flag
# nu_eff_used_in_astrometry
# pseudocolour
# pseudocolour_error
# ra_pseudocolour_corr
# dec_pseudocolour_corr
# parallax_pseudocolour_corr
# pmra_pseudocolour_corr
# pmdec_pseudocolour_corr
# astrometric_matched_transits
# visibility_periods_used
# astrometric_sigma5d_max
# matched_transits
# new_matched_transits
# matched_transits_removed
# ...
